# %% [markdown]
# # Chapter 5 - Experimental results - RGB

# %% [markdown]
# In this Jupyter notebook we present the Validation accuracy, Validation loss charts and the confusion matrices on the test data. \
#
# We added 3 layers to fine tune the pre-trained models:
# the original output layer (a 1000 neuron fully connected dense layer) was removed, a GlobalAveragePooling2D and a
# fully connected Dense layer whith 1024 neurons was added (using a ReLu activation function) and a fully connected prediction layer whith 8 neurons (using as SoftMax activation function ) was added.
#
#
# Image augmentation samplewise_center=True, samplewise_std_normalization=True See https://software.intel.com/content/www/us/en/develop/articles/hands-on-ai-part-14-image-data-preprocessing-and-augmentation.html

# %%
import os
import shutil
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import Image, Markdown
# %matplotlib inline

# %% [markdown]
# [**Index**]\
# [Fine tuned training results](#Fine-tuned-training-results) \
# [Confusion Matrix](#Confusion-matrix) \
# [Classification reports](#Classification-reports)
#
# [Best Scores](#Best-scores)

# %% [markdown]
# # Implemented models

# %% [markdown]
# A list of all implemented models.

# %%
models  = [
	'ResNet50',
	'ResNet50V2',
	'ResNet101V2',
    'ResNet152V2',
	'InceptionV3',
	'Xception',
	'VGG16',
	'VGG19',
	'MobileNet',
	'MobileNetV2',
	'EfficientNetB7',
	'InceptionResNetV2',
	'DenseNet121',
	'NASNetLarge',
]

# %%
# retive data to be posted on github DO NOT USE!!!!
base = '/home/labuser/deeplearning/thesis/solutions/compare-dnn/results'
for model in models:
    print('importing results from %s' % model)
    shutil.copyfile(os.path.join(base, model,model+'_testresults.pkl'),os.path.join(os.getcwd(),'data',model+'_testresults.pkl'))
    shutil.copyfile(os.path.join(base, model,model+'_training.log'),os.path.join(os. getcwd(),'data',model+'_training.log'))
    shutil.copyfile(os.path.join(base, model,model+'_cm.png'),os.path.join(os.getcwd(),'data',model+'_cm.png'))
    shutil.copyfile(os.path.join(base, model,model+'_learn_plot_accuracy.png'),os.path.join(os.getcwd(),'data',model+'_learn_plot_accuracy.png'))
    shutil.copyfile(os.path.join(base, model,model+'_learn_plot_loss.png'),os.path.join(os.getcwd(),'data',model+'_learn_plot_loss.png')) 
    shutil.copyfile(os.path.join(base, model,model+'_classification_report.pkl'),os.path.join(os.getcwd(),'data',model+'_classification_report.pkl'))
# Out:
# importing results from ResNet50
# importing results from ResNet50V2
# importing results from ResNet101V2
# importing results from ResNet152V2
# importing results from InceptionV3
# importing results from Xception
# importing results from VGG16
# importing results from VGG19
# importing results from MobileNet
# importing results from MobileNetV2
# importing results from EfficientNetB7
# importing results from InceptionResNetV2
# importing results from DenseNet121
# importing results from NASNetLarge

# %% [markdown]
# ## Fine tuned training results

# %% [markdown]
# Using a pre-trained model trained 50 epochs on our processed VT ransowmare DataSet with ImageNet Weights \
# The input tensor: \
# 224 x 224 x 3 = 150,528 features \
# 299 x 299 x 3 = 268,203 features \
# 311 x 311 x 3 = 290,163 features \
# We set the minimum image size to 112 x 112 x 3 to limit the effects of rescaling (reshape and resize) images. Because smaller images tend to distort if they are upscalled and making the training less effective.
#
# Training scores max. 50 epochs and batch size 64 - dataset split 80% 20% and a 10% hold-out test set

# %% [markdown]
# ## Validation accuracy - Fine tuned models

# %%
plt.title('Model validation accuracy - Fine tuned models trained 50 epochs')
for model in MODELS:
    result = pd.read_csv(os.path.join(os. getcwd(),'data',model + '_training.log'))
    plt.plot(result.val_accuracy * 100 , label=model)
plt.ylabel('Validation Accuracy %')
plt.xlabel('Epoch')
plt.ylim([20, 100])
plt.legend(loc=0)
plt.savefig('all_models_val_Accuracy.png')
plt.show()

# %% [markdown]
# ## Validation loss - fine tuned models

# %%
plt.title('Model loss - Fine tuned model')
for model in MODELS:
    result = pd.read_csv(os.path.join(os. getcwd(),'data',model + '_training.log'))
    plt.plot(result.val_loss, label=model)
plt.ylabel('Validation Loss')
plt.xlabel('Epoch')
plt.legend(loc=0)
plt.savefig('all_models_val_loss.png')
plt.show()

# %% [markdown]
# ## Testset - accuracy and loss reports

# %% [markdown]
# The accuracy and loss reults on the testdataset

# %%
#combine test results
testdata = {}
for model in MODELS:
    print('importing results from %s' % model)
    testdata[model]=pd.read_pickle((os.path.join(os. getcwd(),'data',model + '_testresults.pkl')))
# Out:
# importing results from ResNet50
# importing results from ResNet50V2
# importing results from ResNet101V2
# importing results from ResNet152V2
# importing results from InceptionV3
# importing results from Xception
# importing results from VGG16
# importing results from VGG19
# importing results from MobileNet
# importing results from MobileNetV2
# importing results from EfficientNetB7
# importing results from InceptionResNetV2
# importing results from DenseNet121
# importing results from NASNetLarge

# %%
dataresults = pd.concat(testdata,axis=0)
dataresults = dataresults.round(decimals=4) # 4 signficant numbers

# %%
# Minimum of 80 procent
dataresults[dataresults['test acc'].ge(0.8)].sort_values(by=['test acc','test loss'],ascending=False)
# Out:
#                      test loss  test acc
# MobileNetV2       0     0.6495    0.9160
# MobileNet         0     0.3466    0.9049
# ResNet50          0     0.4271    0.8748
# NASNetLarge       0     0.7944    0.8605
# InceptionV3       0     0.8289    0.8479
# InceptionResNetV2 0     0.4958    0.8463

# %%
#Test accuracy_scores 
high = dataresults['test acc'].max()
print(dataresults['test acc'].max())
# Out:
# 0.916

# %% [markdown]
# ## Classification reports

# %% [markdown]
# The classification reports of the best scoring models.The model with the best val_accuracy is: MobileNet and MobileNetV2

# %%
class_report = {}
for model in['MobileNet','InceptionResNetV2','NASNetLarge','ResNet152V2','ResNet50','InceptionV3']:
    print('importing results from %s' % model)
    class_report[model] = pd.read_pickle((os.path.join(os.getcwd(),'data',model + '_classification_report.pkl')))
# Out:
# importing results from MobileNet
# importing results from InceptionResNetV2
# importing results from NASNetLarge
# importing results from ResNet152V2
# importing results from ResNet50
# importing results from InceptionV3

# %%
class_report_data = pd.concat(class_report,axis=0)
class_report_data['accuracy']
# Out:
# MobileNet          precision    0.904913
#                    recall       0.904913
#                    f1-score     0.904913
#                    support      0.904913
# InceptionResNetV2  precision    0.846276
#                    recall       0.846276
#                    f1-score     0.846276
#                    support      0.846276
# NASNetLarge        precision    0.860539
#                    recall       0.860539
#                    f1-score     0.860539
#                    support      0.860539
# ResNet152V2        precision    0.556260
#                    recall       0.556260
#                    f1-score     0.556260
#                    support      0.556260
# ResNet50           precision    0.874802
#                    recall       0.874802
#                    f1-score     0.874802
#                    support      0.874802
# InceptionV3        precision    0.851030
#                    recall       0.851030
#                    f1-score     0.851030
#                    support      0.851030
# Name: accuracy, dtype: float64

# %% [markdown]
# Show the best scoring models

# %%
pd.read_pickle(os.path.join(os.getcwd(),'data','MobileNet_classification_report.pkl'))
# Out:
#               benign     cerber     crowti   gandcrab    genasom      locky  \
# precision   0.888889   0.936170   0.888889   0.949495   0.818182   0.712121
# recall      0.888889   0.897959   0.857143   0.949495   0.900000   0.870370
# f1-score    0.888889   0.916667   0.872727   0.949495   0.857143   0.783333
# support    36.000000  49.000000  56.000000  99.000000  20.000000  54.000000
#
#              tescrypt  wannacrypt  accuracy   macro avg  weighted avg
# precision    0.949495         0.6  0.904913    0.842905      0.909609
# recall       0.918567         0.6  0.904913    0.860303      0.904913
# f1-score     0.933775         0.6  0.904913    0.850254      0.906341
# support    307.000000        10.0  0.904913  631.000000    631.000000

# %%
pd.read_pickle(os.path.join(os.getcwd(),'data','MobileNetV2_classification_report.pkl'))
# Out:
#               benign     cerber     crowti   gandcrab  genasom      locky  \
# precision   0.823529   0.936170   0.784615   0.968750      0.9   0.758621
# recall      0.777778   0.897959   0.910714   0.939394      0.9   0.814815
# f1-score    0.800000   0.916667   0.842975   0.953846      0.9   0.785714
# support    36.000000  49.000000  56.000000  99.000000     20.0  54.000000
#
#              tescrypt  wannacrypt  accuracy   macro avg  weighted avg
# precision    0.960265    0.666667  0.909667    0.849827      0.912516
# recall       0.944625    0.600000  0.909667    0.848161      0.909667
# f1-score     0.952381    0.631579  0.909667    0.847895      0.910427
# support    307.000000   10.000000  0.909667  631.000000    631.000000

# %% [markdown]
# ## Confusion matrix

# %% [markdown]
# An overview of all Confusion matrices by models

# %%
cms={}
for model in['MobileNet','InceptionResNetV2','NASNetLarge','ResNet152V2','ResNet50','InceptionV3']:
    cms[model]= os.path.join(os.getcwd(),'data',model+'_cm.png')

# %%
for model in cms:
    display(Markdown('## '+model))
    print(cms[model])
    display(Image(filename=cms[model]))
# Out:
# ## MobileNet
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/MobileNet_cm.png
# ## InceptionResNetV2
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/InceptionResNetV2_cm.png
# ## NASNetLarge
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/NASNetLarge_cm.png
# ## ResNet152V2
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/ResNet152V2_cm.png
# ## ResNet50
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/ResNet50_cm.png
# ## InceptionV3
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/InceptionV3_cm.png

# %%
plt.title('Model validation accuracy - Fine tuned models trained 50 epochs 80 20')
for model in['MobileNet','InceptionResNetV2','NASNetLarge','ResNet152V2','ResNet50','InceptionV3']:
    result = pd.read_csv(os.path.join(os.getcwd(),'data',model+'_training.log'))
    plt.plot(result.val_accuracy * 100 , label=model)
plt.ylabel('Validation Accuracy %')
plt.xlabel('Epoch')
plt.ylim([20, 100])
plt.legend(loc=0)
plt.show()

# %%
plt.title('Model validation loss - Fine tuned model 80 20')
#for model in['MobileNet','InceptionResNetV2','NASNetLarge','ResNet152V2','ResNet50','InceptionV3']:
#for model in['MobileNet','InceptionResNetV2','NASNetLarge','ResNet50','InceptionV3']:
#for model in['MobileNet','InceptionResNetV2','ResNet50','InceptionV3']:
for model in['MobileNet','InceptionResNetV2','ResNet50']:
    result = pd.read_csv(os.path.join(base, model,model+'_training.log'))
    #plt.plot(result.val_loss, label=model)
    plt.plot(result.loss, label=model)
plt.ylabel('Validation Loss')
plt.xlabel('Epoch')
plt.legend(loc=0)
plt.show()

# %%
diags={}
for model in['MobileNet','InceptionResNetV2','NASNetLarge','ResNet152V2','ResNet50','InceptionV3']:
    diags[model] = os.path.join(os.getcwd(),'data',model+'_learn_plot_accuracy.png')
for model in diags:
    display(Markdown('## '+model))
    print(cms[model])
    display(Image(filename=diags[model]))
# Out:
# ## MobileNet
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/MobileNet_cm.png
# ## InceptionResNetV2
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/InceptionResNetV2_cm.png
# ## NASNetLarge
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/NASNetLarge_cm.png
# ## ResNet152V2
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/ResNet152V2_cm.png
# ## ResNet50
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/ResNet50_cm.png
# ## InceptionV3
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/InceptionV3_cm.png

# %%
diags={}
for model in['MobileNet','InceptionResNetV2','NASNetLarge','ResNet152V2','ResNet50','InceptionV3']:
    diags[model] = os.path.join(os.getcwd(),'data', model+'_learn_plot_loss.png')
for model in diags:
    display(Markdown('## '+model))
    print(cms[model])
    display(Image(filename=diags[model]))
# Out:
# ## MobileNet
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/MobileNet_cm.png
# ## InceptionResNetV2
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/InceptionResNetV2_cm.png
# ## NASNetLarge
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/NASNetLarge_cm.png
# ## ResNet152V2
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/ResNet152V2_cm.png
# ## ResNet50
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/ResNet50_cm.png
# ## InceptionV3
# /home/labuser/deeplearning/thesis/datamanagement/dataman/notebooks/data/InceptionV3_cm.png
